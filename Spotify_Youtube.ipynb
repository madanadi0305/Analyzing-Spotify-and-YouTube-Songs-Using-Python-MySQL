# %% [markdown]
# <a href="https://colab.research.google.com/github/madanadi0305/Analyzing-Spotify-and-YouTube-Songs-Using-Python-MySQL/blob/main/Spotify_Youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/sample_data/Spotify_Youtuben.csv")

# %%
df.head(10)
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 5  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 7  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 8  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 9  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# 1                                    Rhinestone Eyes
# 2      New Gold (feat. Tame Impala and Bootie Brown)
# 3                                 On Melancholy Hill
# ...

# %%
df['Channel'].value_counts().keys().unique()
# Out:
# Index(['T-Series', 'SonyMusicIndiaVEVO', 'SonyMusicSouthVEVO',
#        'Zee Music Company', 'RHINO', 'YRF', 'Sony Music India', 'SMTOWN',
#        'Atlantic Records', 'DisneyMusicVEVO',
#        ...
#        'BBBBBBBBeast', 'december hotel', 'Will Siefert', 'Jopin',
#        'Decca Classics', 'LucianoPavarottiVEVO', 'G.Jerry Louison',
#        'Rosa Maria', 'Jack Daniel's', 'Symphonyofflowers'],
#       dtype='object', length=6709)

# %%
df.shape
# Out:
# (20723, 27)

# %%
df.dtypes
# Out:
# Artist               object
# Url_spotify          object
# Track                object
# Album                object
# Album_type           object
# Uri                  object
# Danceability        float64
# Energy              float64
# Key                 float64
# Loudness            float64
# Speechiness         float64
# Acousticness        float64
# Instrumentalness    float64
# Liveness            float64
# Valence             float64
# Tempo               float64
# Duration_ms         float64
# Url_youtube          object
# Title                object
# Channel              object
# Views               float64
# Likes               float64
# Comments            float64
# Description          object
# Licensed             object
# official_video       object
# Stream              float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              577
# dtype: int64

# %%
df['Danceability'].mean()
# Out:
# 0.6197921770184837

# %%
df.describe()
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  20721.000000  20721.000000  20721.000000  20721.000000  20721.000000
# mean       0.619792      0.635245      5.300323     -7.671438      0.096491
# std        0.165268      0.214133      3.576711      4.632751      0.112037
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.519000      0.507000      2.000000     -8.858000      0.035700
# 50%        0.637000      0.666000      5.000000     -6.536000      0.050500
# 75%        0.741000      0.798000      8.000000     -4.931000      0.103000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  20721.000000      20721.000000  20721.000000  20721.000000
# mean       0.291497          0.055948      0.193516      0.529853
# std        0.286277          0.193241      0.168529      0.245429
# ...

# %%
# These columns have only 2 nill values so we can replace it with mean value
df['Danceability']=df['Danceability'].fillna(df['Danceability'].mean())
df['Energy']=df['Energy'].fillna(df['Energy'].mean())
df['Key']=df['Key'].fillna(df['Key'].mean())
df['Loudness']=df['Loudness'].fillna(df['Loudness'].mean())
df['Speechiness']=df['Speechiness'].fillna(df['Speechiness'].mean())
df['Acousticness']=df['Acousticness'].fillna(df['Acousticness'].mean())
df['Instrumentalness']=df['Instrumentalness'].fillna(df['Instrumentalness'].mean())
df['Liveness']=df['Liveness'].fillna(df['Liveness'].mean())
df['Valence']=df['Valence'].fillna(df['Valence'].mean())
df['Tempo']=df['Tempo'].fillna(df['Tempo'].mean())
df['Duration_ms']=df['Duration_ms'].fillna(df['Duration_ms'].mean())

# %%
df['Url_youtube']=df['Url_youtube'].fillna('Not Specified')
df['Title']=df['Title'].fillna("Not Specified")
df['Channel']=df['Channel'].fillna('Not Specified')

# %%
remove_columns=['Url_spotify','Uri','Key','Url_youtube','Description']
df=df.drop(columns=remove_columns)

# %%
df.isna().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          0
# Energy                0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Duration_ms           0
# Title                 0
# Channel               0
# Views               470
# Likes               541
# Comments            569
# Licensed            470
# official_video      470
# Stream              577
# dtype: int64

# %%
df['Views']=df['Views'].fillna(df['Views'].mean())
df['Likes']=df['Likes'].fillna(df['Likes'].mean())
df['Comments']=df['Comments'].fillna(df['Comments'].mean())
df['Stream']=df['Stream'].fillna(df['Stream'].mean())
df['official_video']=df['official_video'].fillna(True)
df['Licensed']=df['Licensed'].fillna(True)

# %%
df=df.rename(columns={'Duration_ms':'Duration_min'})

# %%
df['official_video'].value_counts()
# Out:
# True     16196
# False     4527
# Name: official_video, dtype: int64

# %%
df['Title'].value_counts()
# Out:
# Not Specified                                                                      470
# Color Esperanza 2020 - Various Artists (Official Video)                             18
# Varios Artistas Latinos - EL Ultimo Adios                                           13
# MACKLEMORE & RYAN LEWIS - CAN'T HOLD US FEAT. RAY DALTON (OFFICIAL MUSIC VIDEO)     12
# Die drei Fragezeichen - Das Geheimnis der Geisterinsel                              11
#                                                                                   ...
# Niro - C'est pas assez (Visualizer officiel)                                         1
# Ramito De Violetas (Vídeo Oficial)  - Mi Banda El Mexicano                           1
# Mi Banda El Mexicano - Feliz Feliz (Vídeo con Letra)                                 1
# Mi Banda El Mexicano (Canta Germán Román) - Help! Ayudame - 1995                     1
# MISS YOU HARDSTYLE                                                                   1
# ...

# %%
df[df['Track']=='irrelevant']
# Out:
# Empty DataFrame
# Columns: [Artist, Track, Album, Album_type, Danceability, Energy, Loudness, Speechiness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_min, Title, Channel, Views, Likes, Comments, Licensed, official_video, Stream]
# Index: []
#
# [0 rows x 22 columns]

# %%
df=df[(df['Track'].str.startswith("?")==False)]

# %%
df.isna().sum()
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_min        0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
df['EnergyLiveness']=df['Energy']/df['Liveness']
df['Views']=df['Views'].astype('float64')

# %%
df[(df['Views']!=0 )& (df['Stream']==0)]
# Out:
# Empty DataFrame
# Columns: [Artist, Track, Album, Album_type, Danceability, Energy, Loudness, Speechiness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_min, Title, Channel, Views, Likes, Comments, Licensed, official_video, Stream, EnergyLiveness]
# Index: []
#
# [0 rows x 23 columns]

# %%
c=lambda d:"Youtube" if d['Views']>d['Stream'] else 'Spotify'
df['mostplayedon']=df.apply(c,axis=1)

# %%
df['mostplayedon']
# Out:
# 0        Spotify
# 1        Spotify
# 2        Spotify
# 3        Spotify
# 4        Youtube
#           ...
# 20718    Spotify
# 20719    Spotify
# 20720    Spotify
# 20721    Spotify
# 20722    Spotify
# Name: mostplayedon, Length: 20599, dtype: object

# %%
df['Album_type'].value_counts()
# Out:
# album          14837
# single          4975
# compilation      787
# Name: Album_type, dtype: int64

# %%
df['Album_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Artist'].str.replace("\$\$","\\$\\$").value_counts()
# Out:
# <ipython-input-27-3fc4eea590ab>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Artist'].str.replace("\$\$","\\$\\$").value_counts()
# 50 Cent                  11
# Red Hot Chili Peppers    11
# Cali Y El Dandee         11
# Pedro Capó               11
# Die drei ???             11
#                          ..
# Vaundy                    2
# Mrs. GREEN APPLE          2
# Stars Music Chile         1
# back number               1
# Bootie Brown              1
# Name: Artist, Length: 2074, dtype: int64

# %%
df['Channel'].str.replace("\$\$","\\$\\$").value_counts().head(10).plot(kind='bar')
# Out:
# <ipython-input-28-19454141adce>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Channel'].str.replace("\$\$","\\$\\$").value_counts().head(10).plot(kind='bar')
# <Axes: >

# %%
df['']
# Out:
# 0        0.008360
# 1        0.086900
# 2        0.042500
# 3        0.000015
# 4        0.025300
#            ...
# 20718    0.448000
# 20719    0.028000
# 20720    0.024300
# 20721    0.356000
# 20722    0.002770
# Name: Acousticness, Length: 20599, dtype: float64

# %%
df['mostplayedon'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Views']=df['Views'].astype('int')

# %%
df[['Track','Views']].max()
# Out:
# Track        Únicos
# Views    8079649362
# dtype: object

# %%
df[df['Track']=='Öyle Kolaysa']
# Out:
#             Artist         Track Album Album_type  Danceability  Energy  \
# 15589  Mabel Matiz  Öyle Kolaysa  Maya      album          0.59   0.664
#
#        Loudness  Speechiness  Acousticness  Instrumentalness  ...  \
# 15589    -5.502       0.0331       0.00641               0.0  ...
#
#                             Title     Channel      Views     Likes Comments  \
# 15589  Mabel Matiz - Öyle Kolaysa  netd müzik  317386236  895814.0  49343.0
#
#       Licensed  official_video      Stream  EnergyLiveness  mostplayedon
# 15589     True            True  40923271.0             2.0       Youtube
#
# [1 rows x 24 columns]

# %%
df[['mostplayedon','Track','Views']].sort_values(by='Views',ascending=False).head(2)
# Out:
#      mostplayedon      Track       Views
# 1150      Youtube  Despacito  8079649362
# 367       Youtube  Despacito  8079646911

# %%
df[df['mostplayedon']=='Spotify']['Views'].max()
# Out:
# 2168809930

# %% [markdown]
# #1.Which is the most viewed song track on youtube?

# %%
df[['mostplayedon','Track','Views']].sort_values(by=['Views','mostplayedon'],ascending=False).groupby(by='mostplayedon').head(1)
# Out:
#       mostplayedon      Track       Views
# 1150       Youtube  Despacito  8079649362
# 15254      Spotify    Starboy  2168809930

# %% [markdown]
# #2.Which Song track is streamed most on Spotify?

# %%
df[['mostplayedon','Track','Stream']].sort_values(by=['Stream','mostplayedon'],ascending=False).groupby(by='mostplayedon').head(1)
# Out:
#       mostplayedon            Track        Stream
# 15255      Spotify  Blinding Lights  3.386520e+09
# 12455      Youtube     Shape of You  3.362005e+09

# %% [markdown]
# #3.EnergyLiveness ratio is one of the popular ways to measure the quality of a song, which are the top 5 songs that have the highest energyliveness ratio.

# %%
df[['Track','EnergyLiveness']].sort_values(by='EnergyLiveness',ascending=False).head(5)
# Out:
#                                     Track  EnergyLiveness
# 20636                             Take It       59.113924
# 11694                         Verano Azul       58.000000
# 8844                           Salvavidas       57.655172
# 6555                        Ants Marching       54.522293
# 12253  Eres Mi Sueño - Versión Radio Edit       51.381215
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import altair as alt
# from google.colab import autoviz
# df_5877127944065590415 = autoviz.get_registered_df('df_5877127944065590415')
#
# def histogram(df, colname, maxbins=20, width=100, height=50):
#   return (alt.Chart(df).mark_bar()
#           .encode(
#               x=alt.X(colname, bin=alt.Bin(maxbins=maxbins)),
#               y=alt.Y('count()', axis=alt.Axis(title='count')),
#           )
#           .properties(width=width, height=height))  #  Pixels.
#
# ...

# %% [markdown]
# #4.Let us assume a situation where an artist named Black Eyed Peas wants to analyze his songs. The artist wants to know which platform is capable of keeping his song track more engaged. To check this he assigns you this task and wants you to report to him where his song tracks are more played on. compare the platforms.

# %%
df[df['Artist']=='Black Eyed Peas']['mostplayedon'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='mostplayedon'>

# %%
df['Likes']=df['Likes'].astype('int')

# %% [markdown]
# #5.Gorillaz wants to know their most liked song on youtube. Report to them with their most liked song along with the Energy and Tempo of the song.

# %%
gorillaz=df[df['Artist']=='Gorillaz']

# %%
gorillaz[['Track','Energy','Tempo','Likes','mostplayedon']].sort_values(by='Likes',ascending=False).groupby(by='mostplayedon').head(1)
# Out:
#             Track  Energy    Tempo    Likes mostplayedon
# 0  Feel Good Inc.   0.705  138.559  6220896      Spotify
# 4  Clint Eastwood   0.694  167.953  6197318      Youtube

# %%
youtube=df[df['mostplayedon']=='Youtube']
spotify=df[df['mostplayedon']=='Spotify']
